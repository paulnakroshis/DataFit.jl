# %%
t = [1.0, 2.0, 3.0, 3.5, 4.2, 5.0, 6.1, 7.4]
# Out:
# 8-element Vector{Float64}:
#  1.0
#  2.0
#  3.0
#  3.5
#  4.2
#  5.0
#  6.1
#  7.4

# %%
# determine the spacing between elements of t
# Out:
# UndefVarError: `np` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[2]:2
